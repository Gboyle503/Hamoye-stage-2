# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
data=pd.read_csv('energydata_complete.csv')

# %%
data.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
#    RH_out  Windspeed  Visibility  Tdewpoint        rv1        rv2
# 0    92.0   7.000000   63.000000        5.3  13.275433  13.275433
# 1    92.0   6.666667   59.166667        5.2  18.606195  18.606195
# 2    92.0   6.333333   55.333333        5.1  28.642668  28.642668
# 3    92.0   6.000000   51.500000        5.0  45.410389  45.410389
# 4    92.0   5.666667   47.666667        4.9  10.084097  10.084097
#
# [5 rows x 29 columns]

# %%
data.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# std        4.069813      2.006111      3.254576      2.042884      4.341321
# min       20.463333     17.200000     28.766667     15.100000     27.660000
# 25%       37.900000     20.790000     36.900000     19.530000     35.530000
# 50%       40.500000     22.100000     38.530000     20.666667     38.400000
# 75%       43.260000     23.290000     41.760000     22.100000     42.156667
# max       56.026667     29.236000     50.163333     26.200000     51.090000
#
#        ...            T9          RH_9         T_out   Press_mm_hg  \
# count  ...  19735.000000  19735.000000  19735.000000  19735.000000
# mean   ...     19.485828     41.552401      7.411665    755.522602
# std    ...      2.014712      4.151497      5.317409      7.399441
# min    ...     14.890000     29.166667     -5.000000    729.300000
# 25%    ...     18.000000     38.500000      3.666667    750.933333
# 50%    ...     19.390000     40.900000      6.916667    756.100000
# 75%    ...     20.600000     44.338095     10.408333    760.933333
# max    ...     24.500000     53.326667     26.100000    772.300000
#
#              RH_out     Windspeed    Visibility     Tdewpoint           rv1  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      79.750418      4.039752     38.330834      3.760707     24.988033
# std       14.901088      2.451221     11.794719      4.194648     14.496634
# min       24.000000      0.000000      1.000000     -6.600000      0.005322
# 25%       70.333333      2.000000     29.000000      0.900000     12.497889
# 50%       83.666667      3.666667     40.000000      3.433333     24.897653
# 75%       91.666667      5.500000     40.000000      6.566667     37.583769
# max      100.000000     14.000000     66.000000     15.500000     49.996530
#
#                 rv2
# count  19735.000000
# mean      24.988033
# std       14.496634
# min        0.005322
# 25%       12.497889
# 50%       24.897653
# 75%       37.583769
# max       49.996530
#
# [8 rows x 28 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
#  18  RH_8         19735 non-null  float64
#  19  T9           19735 non-null  float64
#  20  RH_9         19735 non-null  float64
#  21  T_out        19735 non-null  float64
#  22  Press_mm_hg  19735 non-null  float64
#  23  RH_out       19735 non-null  float64
#  24  Windspeed    19735 non-null  float64
#  25  Visibility   19735 non-null  float64
#  26  Tdewpoint    19735 non-null  float64
#  27  rv1          19735 non-null  float64
#  28  rv2          19735 non-null  float64
# dtypes: float64(26), int64(2), object(1)
# memory usage: 4.4+ MB

# %%
pip install skimpy
# Out:
# Requirement already satisfied: skimpy in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (0.0.8)
# Requirement already satisfied: numpy<2.0.0,>=1.22.2 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from skimpy) (1.22.4)
# Requirement already satisfied: pandas<2.0.0,>=1.3.2 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from skimpy) (1.4.2)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from skimpy) (8.1.3)
# Requirement already satisfied: rich<13.0,>=10.9 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from skimpy) (12.6.0)
# Requirement already satisfied: Pygments<3.0.0,>=2.10.0 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from skimpy) (2.11.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.12.1 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from skimpy) (2.13.3)
# Requirement already satisfied: jupyter<2.0.0,>=1.0.0 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from skimpy) (1.0.0)
# Requirement already satisfied: ipykernel<7.0.0,>=6.7.0 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from skimpy) (6.9.1)
# Requirement already satisfied: colorama in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from click<9.0.0,>=8.1.3->skimpy) (0.4.4)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (6.1.12)
# Requirement already satisfied: traitlets<6.0,>=5.1.0 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.1.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (0.1.2)
# Requirement already satisfied: nest-asyncio in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (1.5.5)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (1.5.1)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (8.2.0)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (6.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (61.2.0)
# Requirement already satisfied: decorator in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.18.1)
# Requirement already satisfied: stack-data in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.7.5)
# Requirement already satisfied: backcall in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (3.0.20)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.8.3)
# Requirement already satisfied: jupyter-console in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (6.4.0)
# Requirement already satisfied: nbconvert in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (6.4.4)
# Requirement already satisfied: notebook in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (6.4.8)
# Requirement already satisfied: qtconsole in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (5.3.0)
# Requirement already satisfied: ipywidgets in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (7.6.5)
# Requirement already satisfied: pyzmq>=13 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel<7.0.0,>=6.7.0->skimpy) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel<7.0.0,>=6.7.0->skimpy) (4.9.2)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel<7.0.0,>=6.7.0->skimpy) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel<7.0.0,>=6.7.0->skimpy) (302)
# Requirement already satisfied: pytz>=2020.1 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from pandas<2.0.0,>=1.3.2->skimpy) (2021.3)
# Requirement already satisfied: wcwidth in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel<7.0.0,>=6.7.0->skimpy) (1.16.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from rich<13.0,>=10.9->skimpy) (0.9.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (1.0.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (5.3.0)
# Requirement already satisfied: fastjsonschema in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (2.15.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (4.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (21.4.0)
# Requirement already satisfied: jinja2 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (2.11.3)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (0.13.1)
# Requirement already satisfied: argon2-cffi in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (21.3.0)
# Requirement already satisfied: prometheus-client in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (0.13.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (2.21)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from jinja2->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (2.0.1)
# Requirement already satisfied: defusedxml in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.8.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (4.11.1)
# Requirement already satisfied: bleach in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (4.1.0)
# Requirement already satisfied: testpath in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (2.3.1)
# Requirement already satisfied: packaging in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (21.3)
# Requirement already satisfied: webencodings in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (3.0.4)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from qtconsole->jupyter<2.0.0,>=1.0.0->skimpy) (2.0.1)
# Requirement already satisfied: asttokens in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.2)
# Requirement already satisfied: executing in c:\users\oluwabusayo.boyle\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.8.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from skimpy import skim

# %%
skim(data)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 19735  │ │ float64     │ 26    │                                                          │
# │ │ Number of columns │ 29     │ │ int32       │ 2     │                                                          │
# │ └───────────────────┴────────┘ │ string      │ 1     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┓  │
# │ ┃ column_name        ┃ NA   ┃ NA %    ┃ mean    ┃ sd     ┃ p0         ┃ p25    ┃ p75    ┃ p100    ┃ hist     ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━┩  │
# │ │ Appliances         │    0 │       0 │      98 │    100 │         10 │     50 │    100 │    1100 │    █▁    │  │
# │ │ lights             │    0 │       0 │     3.8 │    7.9 │          0 │      0 │      0 │      70 │    █▁    │  │
# │ │ T1                 │    0 │       0 │      22 │    1.6 │         17 │     21 │     23 │      26 │   ▂██▂▁  │  │
# │ │ RH_1               │    0 │       0 │      40 │      4 │         27 │     37 │     43 │      63 │    ██▂   │  │
# │ │ T2                 │    0 │       0 │      20 │    2.2 │         16 │     19 │     22 │      30 │  ▃█▄▂▁   │  │
# │ │ RH_2               │    0 │       0 │      40 │    4.1 │         20 │     38 │     43 │      56 │    ▄█▂   │  │
# │ │ T3                 │    0 │       0 │      22 │      2 │         17 │     21 │     23 │      29 │  ▁▆█▃▂   │  │
# │ │ RH_3               │    0 │       0 │      39 │    3.3 │         29 │     37 │     42 │      50 │   ▂█▄▃   │  │
# │ │ T4                 │    0 │       0 │      21 │      2 │         15 │     20 │     22 │      26 │  ▁▃█▆▄▁  │  │
# │ │ RH_4               │    0 │       0 │      39 │    4.3 │         28 │     36 │     42 │      51 │   ▆█▅▄▁  │  │
# │ │ T5                 │    0 │       0 │      20 │    1.8 │         15 │     18 │     21 │      26 │  ▁██▄▂   │  │
# │ │ RH_5               │    0 │       0 │      51 │      9 │         30 │     45 │     54 │      96 │   ▁█▃▁   │  │
# │ │ T6                 │    0 │       0 │     7.9 │    6.1 │       -6.1 │    3.6 │     11 │      28 │  ▁▆█▄▁▁  │  │
# │ │ RH_6               │    0 │       0 │      55 │     31 │          1 │     30 │     83 │     100 │  ▅▄▅▆▅█  │  │
# │ │ T7                 │    0 │       0 │      20 │    2.1 │         15 │     19 │     22 │      26 │  ▁▆█▆▄▁  │  │
# │ │ RH_7               │    0 │       0 │      35 │    5.1 │         23 │     32 │     39 │      51 │  ▁▇█▆▃   │  │
# │ │ T8                 │    0 │       0 │      22 │      2 │         16 │     21 │     23 │      27 │  ▁▂▆█▄▁  │  │
# │ │ RH_8               │    0 │       0 │      43 │    5.2 │         30 │     39 │     47 │      59 │  ▁▅█▅▃   │  │
# │ │ T9                 │    0 │       0 │      19 │      2 │         15 │     18 │     21 │      24 │  ▁▅█▇▂▂  │  │
# │ │ RH_9               │    0 │       0 │      42 │    4.2 │         29 │     38 │     44 │      53 │   ▂█▅▃▁  │  │
# │ │ T_out              │    0 │       0 │     7.4 │    5.3 │         -5 │    3.7 │     10 │      26 │  ▁▇█▄▁   │  │
# │ │ Press_mm_hg        │    0 │       0 │     760 │    7.4 │        730 │    750 │    760 │     770 │   ▁▄█▆▂  │  │
# │ │ RH_out             │    0 │       0 │      80 │     15 │         24 │     70 │     92 │     100 │   ▁▂▄▆█  │  │
# │ │ Windspeed          │    0 │       0 │       4 │    2.5 │          0 │      2 │    5.5 │      14 │  ██▅▃▁   │  │
# │ │ Visibility         │    0 │       0 │      38 │     12 │          1 │     29 │     40 │      66 │   ▁▄█▁▂  │  │
# │ │ Tdewpoint          │    0 │       0 │     3.8 │    4.2 │       -6.6 │    0.9 │    6.6 │      16 │  ▁▄█▆▃▁  │  │
# │ │ rv1                │    0 │       0 │      25 │     14 │     0.0053 │     12 │     38 │      50 │  ██████  │  │
# │ │ rv2                │    0 │       0 │      25 │     14 │     0.0053 │     12 │     38 │      50 │  ██████  │  │
# │ └────────────────────┴──────┴─────────┴─────────┴────────┴────────────┴────────┴────────┴─────────┴──────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name               ┃ NA      ┃ NA %       ┃ words per row                ┃ total words              ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ date                      │       0 │          0 │                            2 │                    39000 │  │
# │ └───────────────────────────┴─────────┴────────────┴──────────────────────────────┴──────────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
data.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
sns.regplot(x="T2", y="T6",
data=data)
# Out:
# <AxesSubplot:xlabel='T2', ylabel='T6'>

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split('T2','T6',
test_size=0.3, random_state=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
X, y = data[["T2", "T6"]]

# %%
model.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 model.fit(X, y)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:662, in LinearRegression.fit(self, X, y, sample_weight)
#     658 n_jobs_ = self.n_jobs
#     660 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 662 X, y = self._validate_data(
#     663     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664 )
#     666 if sample_weight is not None:
#     667     sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:581, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     579         y = check_array(y, **check_y_params)
#     580     else:
# --> 581         X, y = check_X_y(X, y, **check_params)
#     582     out = X, y
#     584 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:964, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     961 if y is None:
#     962     raise ValueError("y cannot be None")
# --> 964 X = check_array(
#     965     X,
#     966     accept_sparse=accept_sparse,
#     967     accept_large_sparse=accept_large_sparse,
#     968     dtype=dtype,
#     969     order=order,
#     970     copy=copy,
#     971     force_all_finite=force_all_finite,
#     972     ensure_2d=ensure_2d,
#     973     allow_nd=allow_nd,
#     974     ensure_min_samples=ensure_min_samples,
#     975     ensure_min_features=ensure_min_features,
#     976     estimator=estimator,
#     977 )
#     979 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#     981 check_consistent_length(X, y)
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:761, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     758 if ensure_2d:
#     759     # If input is scalar raise error
#     760     if array.ndim == 0:
# --> 761         raise ValueError(
#     762             "Expected 2D array, got scalar array instead:\narray={}.\n"
#     763             "Reshape your data either using array.reshape(-1, 1) if "
#     764             "your data has a single feature or array.reshape(1, -1) "
#     765             "if it contains a single sample.".format(array)
#     766         )
#     767     # If input is 1D raise error
#     768     if array.ndim == 1:
#
# ValueError: Expected 2D array, got scalar array instead:
# array=T2.
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
data2=data.drop(['date','lights'], axis=1, inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
normalised_df = pd.DataFrame(scaler.fit_transform(data), columns=data.columns)

# %%
target = normalised_df['Appliances']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data, target,
test_size=0.3, random_state=42)

# %%
from sklearn import linear_model

# %%
regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
predicted_values = regr.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predicted_values)
round(mae, 3)
# Out:
# 0.0

# %%
import numpy as np
rss = np.sum(np.square(y_test - predicted_values))
round(rss, 3)
# Out:
# 0.0
